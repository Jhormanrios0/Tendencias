# %% [markdown]
# # Análisis de Datos de Películas
#
# En este notebook, realizaremos un análisis de un conjunto de datos de películas. Los datos incluyen información sobre géneros, palabras clave, reparto, equipo, fecha de lanzamiento, popularidad, ingresos, promedio de votos y conteo de votos.
#
# ## Importación de Librerías
#
# Primero, importamos las librerías necesarias para el análisis.

# %%
import pandas as pd
import numpy as np
import ast
import os
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Carga de Datos
#
# Cargamos los conjuntos de datos `tmdb_5000_movies.csv` y `tmdb_5000_credits.csv`.

# %%
movies = pd.read_csv('./dataSets/tmdb_5000_movies.csv')
credits = pd.read_csv('./dataSets/tmdb_5000_credits.csv' , encoding='utf-8')

# %%
print(movies.shape)
movies.head(1)
# Out:
# (4803, 20)
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                        tagline   title  vote_average  vote_count
# 0  Enter the World of Pandora.  Avatar           7.2       11800

# %%
print(credits.shape)
credits.head(1)
# Out:
# (4803, 4)
#    movie_id   title                                               cast  \
# 0     19995  Avatar  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %% [markdown]
# ## Fusión de Datos
#
# Fusionamos los dos conjuntos de datos en uno solo utilizando la columna `title` y eliminamos las filas con valores nulos.

# %%
movies = movies.merge(credits,on='title')
movies.dropna(inplace=True)

# %%
movies.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
#
#    movie_id                                               cast  \
# 0     19995  [{"cast_id": 242, "character": "Jake Sully", "...
# 1       285  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...

# %% [markdown]
# ## Selección de Columnas
#
# Seleccionamos las columnas relevantes para nuestro análisis.

# %%
movies = movies[['movie_id', 'title', 'overview', 'genres', 'keywords', 'cast', 'crew', 
                 'release_date', 'popularity', 'revenue', 'vote_average', 'vote_count']]

movies.head(1)
# Out:
#    movie_id   title                                           overview  \
# 0     19995  Avatar  In the 22nd century, a paraplegic Marine is di...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew release_date  popularity  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...   2009-12-10  150.437577
#
#       revenue  vote_average  vote_count
# 0  2787965087           7.2       11800

# %% [markdown]
# ## Conversión de Datos
#
# Definimos una función para convertir las columnas `genres` y `keywords` de cadenas de texto a listas de nombres.

# %%
import ast

def convert(text):
    try:
        return [i['name'] for i in ast.literal_eval(text)]
    except (ValueError, SyntaxError, TypeError):
        return []

movies['genres'] = movies['genres'].apply(convert)
movies['keywords'] = movies['keywords'].apply(convert)

movies.head(2)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew release_date  popularity  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...   2009-12-10  150.437577
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...   2007-05-19  139.082615
#
#       revenue  vote_average  vote_count
# 0  2787965087           7.2       11800
# 1   961000000           6.9        4500

# %% [markdown]
# ### Evaluación de Literales en Python
#
# El siguiente código utiliza el módulo `ast` de Python para evaluar una cadena de texto que representa una lista de diccionarios. La función `ast.literal_eval` se utiliza para convertir esta cadena en una estructura de datos de Python (en este caso, una lista de diccionarios).

# %%
import ast
ast.literal_eval('[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]')
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %%
import ast

def convert3(text):
    L = []
    try:
        parsed = ast.literal_eval(text)
        counter = 0
        for i in parsed:
            if counter < 3:
                L.append(i['name'])
                counter += 1
    except (ValueError, SyntaxError):
        pass
    return L


movies['cast'] = movies['cast'].apply(convert3)


movies.head(2)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
#
#                                                cast  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley]
#
#                                                 crew release_date  popularity  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...   2009-12-10  150.437577
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...   2007-05-19  139.082615
#
#       revenue  vote_average  vote_count
# 0  2787965087           7.2       11800
# 1   961000000           6.9        4500

# %%
import ast

def fetch_director(text):
    L = []
    try:
        parsed = ast.literal_eval(text)
        for i in parsed:
            if i['job'] == 'Director':
                L.append(i['name'])
    except (ValueError, SyntaxError):
        pass
    return L

# Aplica la función fetch_director a la columna 'crew'
movies['crew'] = movies['crew'].apply(fetch_director)

# Muestra una muestra del DataFrame para verificar
movies.sample(2)
# Out:
#       movie_id                  title  \
# 566        920                   Cars
# 1368       350  The Devil Wears Prada
#
#                                                overview  \
# 566   Lightning McQueen, a hotshot rookie race car d...
# 1368  The Devil Wears Prada is about a young journal...
#
#                                       genres  \
# 566   [Animation, Adventure, Comedy, Family]
# 1368                [Comedy, Drama, Romance]
#
#                                                keywords  \
# 566   [car race, car journey, village and town, auto...
# 1368  [paris, journalist, journalism, world of fasio...
#
#                                             cast                        crew  \
# 566      [Owen Wilson, Paul Newman, Bonnie Hunt]  [John Lasseter, Joe Ranft]
# 1368  [Meryl Streep, Anne Hathaway, Emily Blunt]             [David Frankel]
#
#      release_date  popularity    revenue  vote_average  vote_count
# 566    2006-06-08   82.643036  461983149           6.6        3877
# 1368   2006-06-30   83.893257  326551094           7.0        3088

# %%
movies['overview'] = movies['overview'].apply(lambda x:x.split())
movies.sample(2)
# Out:
#       movie_id                    title  \
# 1452     13056       Punisher: War Zone
# 1171      1213  The Talented Mr. Ripley
#
#                                                overview  \
# 1452  [Waging, his, one-man, war, on, the, world, of...
# 1171  [Tom, Ripley, is, a, calculating, young, man, ...
#
#                         genres  \
# 1452           [Action, Crime]
# 1171  [Thriller, Crime, Drama]
#
#                                                keywords  \
# 1452  [broken neck, fbi agent, wall safe, trashed ho...
# 1171  [venice, italy, gay, new york, lovesickness, d...
#
#                                            cast                 crew  \
# 1452  [Ray Stevenson, Dominic West, Julie Benz]     [Lexi Alexander]
# 1171    [Matt Damon, Gwyneth Paltrow, Jude Law]  [Anthony Minghella]
#
#      release_date  popularity    revenue  vote_average  vote_count
# 1452   2008-12-05   17.112498   10089373           5.6         294
# 1171   1999-12-25   31.385257  128798265           7.0         767

# %%
def collapse(L):
    L1 = []
    for i in L:
        L1.append(i.replace(" ", ""))
    return L1

# Aplica la función collapse a las columnas correspondientes
movies['cast'] = movies['cast'].apply(collapse)
movies['crew'] = movies['crew'].apply(collapse)
movies['genres'] = movies['genres'].apply(collapse)
movies['keywords'] = movies['keywords'].apply(collapse)

# Muestra las primeras filas para verificar
movies.head(2)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
#
#                                             cast             crew  \
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]   [JamesCameron]
# 1     [JohnnyDepp, OrlandoBloom, KeiraKnightley]  [GoreVerbinski]
#
#   release_date  popularity     revenue  vote_average  vote_count
# 0   2009-12-10  150.437577  2787965087           7.2       11800
# 1   2007-05-19  139.082615   961000000           6.9        4500

# %%
# Crea la columna tags concatenando las columnas especificadas
movies['tags'] = (
    movies['overview'].astype(str) + ' ' +
    movies['genres'].apply(' '.join) + ' ' +
    movies['keywords'].apply(' '.join) + ' ' +
    movies['cast'].apply(' '.join) + ' ' +
    movies['crew'].apply(' '.join) + ' ' +
    movies['popularity'].astype(str) + ' ' +
    movies['revenue'].astype(str) + ' ' +
    movies['vote_average'].astype(str) + ' ' +
    movies['vote_count'].astype(str)
)

# Muestra las primeras filas para verificar
movies.head(2)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
#
#                                             cast             crew  \
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]   [JamesCameron]
# 1     [JohnnyDepp, OrlandoBloom, KeiraKnightley]  [GoreVerbinski]
#
#   release_date  popularity     revenue  vote_average  vote_count  \
# 0   2009-12-10  150.437577  2787965087           7.2       11800
# 1   2007-05-19  139.082615   961000000           6.9        4500
#
#                                                 tags
# 0  ['In', 'the', '22nd', 'century,', 'a', 'parapl...
# 1  ['Captain', 'Barbossa,', 'long', 'believed', '...

# %%
new = movies.drop(columns=['overview', 'genres', 'keywords', 'cast', 'crew', 'popularity', 'revenue', 'vote_average', 'vote_count'])
new.head(2)
# Out:
#    movie_id                                     title release_date  \
# 0     19995                                    Avatar   2009-12-10
# 1       285  Pirates of the Caribbean: At World's End   2007-05-19
#
#                                                 tags
# 0  ['In', 'the', '22nd', 'century,', 'a', 'parapl...
# 1  ['Captain', 'Barbossa,', 'long', 'believed', '...

# %%
new['tags'] = new['tags'].apply(lambda x: " ".join(x) if isinstance(x, list) else x)

new.head(2)
# Out:
#    movie_id                                     title release_date  \
# 0     19995                                    Avatar   2009-12-10
# 1       285  Pirates of the Caribbean: At World's End   2007-05-19
#
#                                                 tags
# 0  [ ' I n ' ,   ' t h e ' ,   ' 2 2 n d ' ,   ' ...
# 1  [ ' C a p t a i n ' ,   ' B a r b o s s a , ' ...
